# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('df_test.csv')

# %%
df.shape
# Out:
# (6700, 14)

# %%
df.head()
# Out:
#          date     price  bedrooms  grade  has_basement  living_in_m2  \
# 0  2014-09-26  305000.0         2      1         False      76.18046
# 1  2014-05-14  498000.0         3      2          True     210.88981
# 2  2015-03-23  590000.0         2      4         False     262.91549
# 3  2014-07-15  775000.0         3      3         False     159.79316
# 4  2015-04-14  350000.0         2      1         False      92.90300
#
#    renovated  nice_view  perfect_condition  real_bathrooms  has_lavatory  \
# 0      False      False               True               1         False
# 1      False      False              False               2          True
# 2      False      False              False               2          True
# 3      False      False              False               1          True
# 4      False      False              False               1          True
#
#    single_floor  month  quartile_zone
# 0          True      9              2
# ...

# %% [markdown]
# ##For simple linear regression, predict the house price based on only on the area of the **living** space.

# %%
X = df['living_in_m2'].to_numpy().reshape(-1,1)
X.size
# Out:
# 6700

# %%
Y = df['price'].to_numpy().reshape(-1,1)
Y.size
# Out:
# 6700

# %%
learning_rate = 0.00005
iterations = 1000000
m = len(X)

w = 0
b = 0

for i in range(iterations):
  f_wb = X*w +b
  cost  = f_wb - Y
  w  = w - learning_rate * (1/m) * np.sum(cost*X)
  b  = b - learning_rate * (1/m) * np.sum(cost)
  print(w, b, (1/m) * np.sum(cost)) if i % 1000 == 0 else None
# Out:
# 4746.243265509793 23.770614000000002 -475412.28
# 2521.4439598933627 869.1093257056749 -17068.14095966675
# 2517.3370213490425 1719.8703937204082 -16962.516664223673
# 2513.2554981379562 2565.3666213162687 -16857.546013006617
# 2509.199232980135 3405.630589373683 -16753.2249610108
# 2505.1680695689215 4240.694677149937 -16649.54948826368
# 2501.1618525649433 5070.591063526858 -16546.51559966986
# 2497.1804275901277 5895.351728250859 -16444.11932485677
# 2493.2236412217558 6715.008453165196 -16342.356718022425
# 2489.2913409865473 7529.592823434775 -16241.223857783092
# 2485.3833753547847 8339.136228763173 -16140.716847021575
# 2481.4995937344756 9143.669864602301 -16040.831812737963
# 2477.639846465551 9943.224733354455 -15941.564905899859
# 2473.8039848140957 10737.831645567006 -15842.912301294285
# 2469.991860966617 11527.521221119716 -15744.870197379963
# 2466.203328024351 12312.323890404561 -15647.434816141276
# 2462.438239997599 13092.269895498444 -15550.60240294206
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(X, Y)

plt.plot(np.arange(1,400, 1), np.arange(1,400, 1)*w + b, color='r')

plt.show()
